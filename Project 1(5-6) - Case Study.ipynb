# %% [markdown]
# # Top Industries
# Send Feedback
# Given File 'startup_funding.csv'
# Problem Statement :
# Which type of companies got more easily funding. To answer this question, find -
# Top 5 industries and percentage of the total amount funded to that industry. (among top 5 only)
# Print the industry name and percentage of the amount funded with 2 decimal place after rounding off.
# Note :
# Ecommerce is the right word in IndustryVertical, so correct it.
# Print the industry in descending order with respect to the percentage of the amount funded.
# Output Format :
# industry1 percent1
# industry2 percent2
# industry3 percent3
# . . .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
startup = pd.read_csv("startup_funding.csv", encoding='latin1')
df = startup.copy()

# %%
df.loc[df.IndustryVertical == 'ecommerce', 'IndustryVertical'] = 'Ecommerce'
df.loc[df.IndustryVertical == 'ECommerce', 'IndustryVertical'] = 'Ecommerce'
df.loc[df.IndustryVertical == 'eCommerce', 'IndustryVertical'] = 'Ecommerce'
df.dropna(subset = ["IndustryVertical"],inplace = True)
df.loc[df["AmountInUSD"].isnull(),"AmountInUSD"]= '0'
amount = df["AmountInUSD"].values
for i in range(len(amount)):
     if isinstance(amount[i], str):
            amount[i] = ''.join(amount[i].split(','))
df["AmountInUSD"]=amount.astype(int)
funds = df.groupby("IndustryVertical")["AmountInUSD"].sum()
np_fund=funds.values
np_investment =funds.index
np_investment = np_investment[np.argsort(np_fund)][::-1]
np_fund = np.sort(np_fund)[::-1]
# Out:
# Index(['Ecommerce', 'Consumer Internet', 'Technology', 'Online Marketplace',
#        'E-Commerce & M-Commerce platform',
#        'Car Aggregator & Retail Mobile App', 'Ecommerce Marketplace',
#        'Cab Aggregator', 'Cab rental Mobile app', 'Logistics',
#        ...
#        'Furniture and appliances rental platform',
#        'Real Estate Insights platform', 'Railways Information Mobile app',
#        'Gourmet Food Discovery & Delivery platform', 'Gourmet Meals Delivery',
#        'Grocery retail Mobile app', 'Gym Discovery platform',
#        'Health & Fitness App', 'Health, Wellness & Beauty Services App',
#        '360-degree view creating platform'],
#       dtype='object', name='IndustryVertical', length=740)

# %%
np_x = np_investment[:5]
np_y = np_fund[:5]
sum_fund = np.sum(np_y)
for i in range(len(np_x)):
    percentage = (np_y[i]/sum_fund)*100
    print(np_x[i],format(percentage,".2f"))
# Out:
# Ecommerce 40.53
# Consumer Internet 35.95
# Technology 10.45
# Online Marketplace 6.63
# E-Commerce & M-Commerce platform 6.44

# %%
explode = [0.0,0.1,0.4,0.5,0.6]
colors = ["blue","Magenta","Pink","Purple","Grey"]
plt.pie(np_y,labels=np_x,colors=colors,explode=explode,autopct="%.1f%%")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
startup = pd.read_csv("startup_funding.csv", encoding='latin1')
df = startup.copy()
df.loc[df.IndustryVertical == 'ecommerce', 'IndustryVertical'] = 'Ecommerce'
df.loc[df.IndustryVertical == 'ECommerce', 'IndustryVertical'] = 'Ecommerce'
df.loc[df.IndustryVertical == 'eCommerce', 'IndustryVertical'] = 'Ecommerce'
df.dropna(subset = ["IndustryVertical"],inplace = True)
df.loc[df["AmountInUSD"].isnull(),"AmountInUSD"]= '0'
amount = df["AmountInUSD"].values
for i in range(len(amount)):
     if isinstance(amount[i], str):
            amount[i] = ''.join(amount[i].split(','))
df["AmountInUSD"]=amount.astype(int)
funds = df.groupby("IndustryVertical")["AmountInUSD"].sum()
np_fund=funds.values
np_investment =funds.index
np_investment = np_investment[np.argsort(np_fund)][::-1]
np_fund = np.sort(np_fund)[::-1]
np_x = np_investment[:5]
np_y = np_fund[:5]
sum_fund = np.sum(np_y)
for i in range(len(np_x)):
    percentage = (np_y[i]/sum_fund)*100
    print(np_x[i],format(percentage,".2f"))
explode = [0.0,0.1,0.4,0.5,0.6]
colors = ["blue","Magenta","Pink","Purple","Grey"]
plt.pie(np_y,labels=np_x,colors=colors,explode=explode,autopct="%.1f%%")
plt.show()
# Out:
# Ecommerce 40.53
# Consumer Internet 35.95
# Technology 10.45
# Online Marketplace 6.63
# E-Commerce & M-Commerce platform 6.44

# %% [markdown]
# # Top startups
# Send Feedback
# Given File 'startup_funding.csv'
# Problem Statement :
# Find top 5 startups with most amount of total funding.
# Print the startup name in descending order with respect to amount of funding.
# Note:
# Ola, Flipkart, Oyo, Paytm are important startups, so correct their names. There are many errors in startup names, ignore correcting all, just handle important ones.
# Output Format :
# startup1
# startup2
# startup3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
startup = pd.read_csv("startup_funding.csv", encoding='latin1')
df = startup.copy()

# %%
df.loc[df["StartupName"].isin(["Ola Cabs","Olacabs"]),"StartupName"]="Ola"
df.loc[df["StartupName"].isin(["Flipkart.com"]),"StartupName"]="Flipkart"
df.loc[df["StartupName"].isin(["Oyo Rooms","OYOfit","Oyorooms","OyoRooms"]),"StartupName"]="Oyo"
df.loc[df["StartupName"].isin(["Paytm Marketplace","Paytm"]),"StartupName"]="Paytm"
df.loc[df["AmountInUSD"].isnull(),"AmountInUSD"]= '0'
amount = df["AmountInUSD"].values
for i in range(len(amount)):
     if isinstance(amount[i], str):
            amount[i] = ''.join(amount[i].split(','))
df["AmountInUSD"]=amount.astype(int)

# %%
sorted_data  = df.groupby("StartupName")["AmountInUSD"].sum()
amount = sorted_data.values
firm = sorted_data.index
np_firm = np.array(firm)
np_amount = np.array(amount)
np_firm = np_firm[np.argsort(np_amount)][::-1]
np_amount = np.sort(np_amount)[:-6:-1]
np_firm =np_firm[:5]
for i in range(len(np_firm)):
    print(np_firm[i])
np_amount
# Out:
# Paytm
# Flipkart
# Ola
# Snapdeal
# Oyo
# array([2340000000, 2259700000, 1899500000,  700000000,  612000000],
#       dtype=int64)

# %%
plt.bar(np_firm,np_amount,width = 0.5)
plt.xticks(rotation=90)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
startup = pd.read_csv("startup_funding.csv", encoding='latin1')
df = startup.copy()
df.loc[df["StartupName"].isin(["Ola Cabs","Olacabs"]),"StartupName"]="Ola"
df.loc[df["StartupName"].isin(["Flipkart.com"]),"StartupName"]="Flipkart"
df.loc[df["StartupName"].isin(["Oyo Rooms","OYOfit","Oyorooms","OyoRooms"]),"StartupName"]="Oyo"
df.loc[df["StartupName"].isin(["Paytm Marketplace","Paytm"]),"StartupName"]="Paytm"
df.loc[df["AmountInUSD"].isnull(),"AmountInUSD"]= '0'
amount = df["AmountInUSD"].values
for i in range(len(amount)):
     if isinstance(amount[i], str):
            amount[i] = ''.join(amount[i].split(','))
df["AmountInUSD"]=amount.astype(int)
sorted_data  = df.groupby("StartupName")["AmountInUSD"].sum()
amount = sorted_data.values
firm = sorted_data.index
np_firm = np.array(firm)
np_amount = np.array(amount)
np_firm = np_firm[np.argsort(np_amount)][::-1]
np_amount = np.sort(np_amount)[:-6:-1]
np_firm =np_firm[:5]
for i in range(len(np_firm)):
    print(np_firm[i])
plt.bar(np_firm,np_amount,width = 0.5)
plt.xticks(rotation=90)
plt.show()
# Out:
# Paytm
# Flipkart
# Ola
# Snapdeal
# Oyo
